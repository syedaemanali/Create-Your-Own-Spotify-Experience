# %% [markdown]
# ***Loading Audio Data***

# %%
import zipfile
import os
import librosa

# Path to the ZIP file
zip_file_path = "E:\\fma_small.zip"

# Directory to extract files
output_dir = "D:\\audio_sample"

# Function to get total size of extracted files in GB
def get_extracted_size(output_dir):
    total_size = sum(os.path.getsize(os.path.join(root, file)) for root, _, files in os.walk(output_dir) for file in files)
    total_size_gb = total_size / (1024 ** 3)  # Convert bytes to GB
    return total_size_gb

# Function to extract all files from a ZIP archive and load audio files in chunks of approximately 5 GB each
def extract_all_and_load_in_chunks(zip_file, output_dir, target_chunk_size_gb=5):
    audio_files = []
    with zipfile.ZipFile(zip_file, 'r') as zip_ref:
        # Get a list of all files in the archive
        file_list = zip_ref.namelist()

        # Calculate total size of the archive
        total_size_gb = sum(zip_ref.getinfo(file).file_size for file in file_list) / (1024 ** 3)

        # Calculate number of chunks based on target chunk size
        num_chunks = int(total_size_gb / target_chunk_size_gb) + 1

        # Extract and load data in chunks
        for i in range(num_chunks):
            start_index = i * len(file_list) // num_chunks
            end_index = (i + 1) * len(file_list) // num_chunks
            
            # Print the current chunk being processed
            print(f"Processing chunk {i + 1}/{num_chunks}")

            # Extract and load audio files in the current chunk
            for file in file_list[start_index:end_index]:
                zip_ref.extract(file, path=output_dir)

                # Check if the extracted file is an audio file
                if file.endswith('.mp3'):  # Adjust file extension as needed
                    file_path = os.path.join(output_dir, file)
                    # Load audio file using librosa
                    try:
                        y, sr = librosa.load(file_path, sr=None, mono=True)
                        audio_files.append((file_path, y, sr))
                    except Exception as e:
                        print(f"Error loading audio file '{file_path}': {str(e)}")

    return audio_files

# Create output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Extract all files from the ZIP archive and load them in chunks of approximately 5 GB each
audio_files = extract_all_and_load_in_chunks(zip_file_path, output_dir)

# Now you have a list of tuples containing file paths, audio data, and sample rates
# Each tuple represents one audio file in the sample
# Out:
# Processing chunk 1/2

# %%
import os
import librosa
import IPython.display as ipd

# Directory containing the audio files
AUDIO_DIR = "D:\\audio_sample"

# Function to get the path of an audio file
def get_audio_paths(dir_path):
    audio_paths = []
    for root, _, files in os.walk(dir_path):
        for file in files:
            if file.endswith('.mp3'):  # Adjust file extension as needed
                audio_paths.append(os.path.join(root, file))
    return audio_paths

# Example: Load and listen to audio files
for audio_file in get_audio_paths(AUDIO_DIR):
    print('File: {}'.format(audio_file))

    try:
        # Load audio file using Librosa
        x, sr = librosa.load(audio_file, sr=None, mono=True)

        # Get information about the loaded audio data
        duration_sec = librosa.get_duration(y=x, sr=sr)
        num_samples = len(x)

        print('Duration: {:.2f}s, {} samples'.format(duration_sec, num_samples))

        # Set the start and end times for playback
        start_sec, end_sec = 7, 17  # Adjust start and end times as needed

        # Listen to the audio within the specified time range
        ipd.Audio(data=x[int(start_sec*sr):int(end_sec*sr)], rate=sr)
    except Exception as e:
        print(f'Error processing {audio_file}: {str(e)}')
        continue  # Skip processing this file and move to the next one
# Out:
# File: D:\audio_sample\fma_small\000\000002.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\000\000005.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\000\000010.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\000\000140.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\000\000141.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\000\000148.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\000\000182.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\000\000190.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\000\000193.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\000\000194.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\000\000197.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\000\000200.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\000\000203.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\000\000204.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\000\000207.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\000\000210.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\000\000211.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\000\000212.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\000\000213.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\000\000255.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\000\000256.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\000\000368.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\000\000424.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\000\000459.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\000\000534.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\000\000540.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\000\000546.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\000\000574.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\000\000602.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\000\
mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\033\033068.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\033\033069.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\033\033070.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\033\033071.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\033\033072.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\033\033123.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\033\033124.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\033\033203.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\033\033216.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\033\033221.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\033\033278.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\033\033415.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\033\033422.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\033\033424.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\033\033426.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\033\033446.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\033\033459.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\033\033460.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\033\033461.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\033\033465.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\033\033477.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\033\033486.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\033\033538.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\033\033992.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\034\034003.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\034\034147.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\034\034167.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\034\034257.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\034\034258.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\034\034263.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\034\034484.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\034\034510.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\034\034511.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\034\034994.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\034\034996.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\035\035007.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\035\035008.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\035\035182.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\035\035184.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\035\035198.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\035\035199.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\035\035204.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\035\035296.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\035\035299.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\035\035443.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\035\035444.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\035\035462.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\035\035527.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\035\035534.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\035\035535.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\035\035537.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\035\035539.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\035\035541.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\035\035543.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\035\035544.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\035\035545.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\035\035549.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\035\035550.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\035\035569.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\035\035571.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\035\035608.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\035\035734.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\036\036096.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\036\036097.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\036\036099.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\036\036143.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\036\036144.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\036\036145.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\036\036146.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\036\036147.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\036\036245.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\036\036257.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\036\036258.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\036\036261.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\036\036272.mp3
# Duration: 29.99s, 1439471 samples
# File: D:\audio_sample\fma_small\036\036273.mp3
# Duration: 29.99s, 1439471 samples
# File: D:\audio_sample\fma_small\036\036275.mp3
# Duration: 29.99s, 1439471 samples
# File: D:\audio_sample\fma_small\036\036277.mp3
# Duration: 29.99s, 1439471 samples
# File: D:\audio_sample\fma_small\036\036302.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\036\036304.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\036\036322.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\036\036333.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\036\036371.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\036\036380.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\036\036388.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\036\036428.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\036\036435.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\036\036481.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\036\036526.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\036\036560.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\036\036567.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\036\036614.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\036\036615.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\036\036616.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\036\036618.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\036\036643.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\036\036659.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\036\036799.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\036\036959.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\036\036961.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\036\036965.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\036\036966.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\036\036983.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\036\036984.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\036\036985.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\036\036986.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\036\036987.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\036\036988.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\036\036990.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\036\036992.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\036\036994.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\036\036997.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\036\036998.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\036\036999.mp3
# Duration: 29.99s, 1439471 samples
# File: D:\audio_sample\fma_small\037\037041.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\037\037111.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\037\037113.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\037\037119.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\037\037121.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\037\037131.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\037\037136.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\037\037141.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\037\037147.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\037\037324.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\037\037325.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\037\037368.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\037\037369.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\037\037416.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\037\037417.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\037\037423.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\037\037538.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\037\037592.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\037\037725.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\037\037727.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\037\037730.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\037\037731.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\037\037779.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\037\037781.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\037\037784.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\037\037859.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\037\037911.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\037\037920.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\038\038312.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\038\038321.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\038\038323.mp3
# Duration: 29.98s, 1321967 samples
# File: D:\audio_sample\fma_small\038\038326.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\038\038351.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\038\038352.mp3
# Duration: 30.00s, 1323119 samples
# File: D:\audio_sample\fma_small\038\038353.mp3
# Error processing D:\audio_sample\fma_small\038\038353.mp3:
# C:\Users\admin\AppData\Local\Temp\ipykernel_6504\2077524693.py:23: UserWarning: PySoundFile failed. Trying audioread instead.
#   x, sr = librosa.load(audio_file, sr=None, mono=True)

# %% [markdown]
# ***Pre-Processing Audio Data***

# %%
import os
import numpy as np
import librosa
import soundfile as sf  # Import soundfile for WAV support

def get_audio_paths(directory):
    audio_paths = []  # List to store audio file paths
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith(".mp3"):  # Adjust file extension as needed
                audio_paths.append(os.path.join(root, file))
    return audio_paths

def process_in_chunks(audio_data):
    yield audio_data, 0  # Yield the entire audio data as one chunk

def enhance_audio_chunk(chunk):
    try:
        # Apply audio effects to the chunk (e.g., equalization, noise reduction, compression)
        # For equalization and noise reduction, you can implement custom processing
        
        # Apply equalization (example: increase low frequencies)
        equalized_audio = chunk * np.array([1.2 if f < 500 else 1.0 for f in range(len(chunk))])
        
        # Apply noise reduction (example: simple moving average filter)
        window_size = 100  # Adjust window size as needed
        
        if len(equalized_audio) < window_size:
            # If audio data is too short, skip noise reduction
            noise_reduced_audio = equalized_audio
        else:
            noise_reduced_audio = np.convolve(equalized_audio, np.ones(window_size) / window_size, mode='same')
        
        # Apply dynamic range compression
        threshold = 0.2  # Adjust threshold as needed
        compression_ratio = 2  # Adjust compression ratio as needed
        compressed_audio = compress_signal(noise_reduced_audio, threshold, compression_ratio)
        
        # Apply normalization
        normalized_audio = librosa.util.normalize(compressed_audio)
        
        enhanced_audio_chunk = normalized_audio
        
        return enhanced_audio_chunk
    except Exception as e:
        print("Error in enhance_audio_chunk:", e)
        return chunk

def compress_signal(signal, threshold, ratio):
    """
    Apply dynamic range compression to the input signal.

    Args:
    - signal (ndarray): Input audio signal.
    - threshold (float): Threshold above which compression starts.
    - ratio (float): Compression ratio.

    Returns:
    - compressed_signal (ndarray): Compressed audio signal.
    """
    # Compute the mask for compression
    mask = np.where(np.abs(signal) > threshold, 1, 0)
    # Apply compression to the masked signal
    compressed_signal = signal * (1 - mask) + mask * (signal - threshold) / ratio
    return compressed_signal

def adjust_energy_level(chunk, min_energy, max_energy):
    """
    Adjust the energy level of the audio chunk to be within an acceptable range.

    Args:
    - chunk (ndarray): Input audio chunk.
    - min_energy (float): Minimum acceptable energy level.
    - max_energy (float): Maximum acceptable energy level.

    Returns:
    - adjusted_chunk (ndarray): Adjusted audio chunk.
    """
    try:
        # Calculate the energy of the audio chunk
        energy = np.sum(np.abs(chunk) ** 2)
        
        # Perform energy level adjustment if necessary
        if energy < min_energy:
            # Increase the volume to bring the energy level up to the minimum
            adjustment_factor = np.sqrt(min_energy / energy)
            adjusted_chunk = chunk * adjustment_factor
        elif energy > max_energy:
            # Decrease the volume to bring the energy level down to the maximum
            adjustment_factor = np.sqrt(max_energy / energy)
            adjusted_chunk = chunk * adjustment_factor
        else:
            # Energy level is within the acceptable range, no adjustment needed
            adjusted_chunk = chunk
        
        return adjusted_chunk
    except Exception as e:
        print("Error in adjust_energy_level:", e)
        return chunk

# Constants
AUDIO_DIR = "D:\\audio_sample"
OUTPUT_DIR = "D:\\processed_audio_wav"  # Adjust the output directory as needed
os.makedirs(OUTPUT_DIR, exist_ok=True)  # Ensure the output directory exists
MIN_ENERGY = 1e6  # Adjust the minimum energy threshold as needed
MAX_ENERGY = 1e10  # Adjust the maximum energy threshold as needed

# Get audio paths
audio_paths = get_audio_paths(AUDIO_DIR)

# Process audio data in chunks
for folder_path in audio_paths:
    try:
        audio_data, sr = librosa.load(folder_path, sr=None, mono=True)
        
        # Create subfolder structure in the output directory
        relative_path = os.path.relpath(folder_path, AUDIO_DIR)
        output_folder = os.path.join(OUTPUT_DIR, os.path.dirname(relative_path))
        os.makedirs(output_folder, exist_ok=True)
        
        print("Pre-processing folder:", os.path.dirname(relative_path))
        
        for chunk, chunk_index in process_in_chunks(audio_data):
           # print("Pre- Processing f:", os.path.basename(folder_path))
            
            # Apply audio enhancement to the chunk
            enhanced_chunk = enhance_audio_chunk(chunk)
           # print("Enhancing audio for folder:", os.path.basename(folder_path))
            
            # Adjust energy level if necessary
mp3 in folder: D:\processed_audio_wav\fma_small\001
# Pre-processing folder: fma_small\001
# Saved enhanced audio for folder: 001930.mp3 in folder: D:\processed_audio_wav\fma_small\001
# Pre-processing folder: fma_small\002
# Saved enhanced audio for folder: 002012.mp3 in folder: D:\processed_audio_wav\fma_small\002
# Pre-processing folder: fma_small\002
# Saved enhanced audio for folder: 002096.mp3 in folder: D:\processed_audio_wav\fma_small\002
# Pre-processing folder: fma_small\002
# Saved enhanced audio for folder: 002097.mp3 in folder: D:\processed_audio_wav\fma_small\002
# Pre-processing folder: fma_small\002
# Saved enhanced audio for folder: 002099.mp3 in folder: D:\processed_audio_wav\fma_small\002
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003263.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003264.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003265.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003266.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003270.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003271.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003272.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003273.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003274.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003492.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003532.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003533.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003534.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003535.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003537.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003538.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003573.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003598.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003624.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003707.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003708.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003720.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003721.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003722.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003724.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003725.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003761.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003762.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003763.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003765.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003766.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003775.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003776.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003777.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003778.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003779.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003832.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003833.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003840.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003880.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003895.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003896.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003904.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003905.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003906.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003908.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003909.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003910.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003911.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003912.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003913.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003920.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003921.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\003
# Saved enhanced audio for folder: 003950.mp3 in folder: D:\processed_audio_wav\fma_small\003
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004013.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004017.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004022.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004037.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004066.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004067.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004068.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004069.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004070.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004071.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004072.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004073.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004074.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004075.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004076.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004077.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004078.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004079.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004080.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004091.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004092.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004093.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004094.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004095.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004096.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004097.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004098.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004099.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004100.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004101.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004102.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004103.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004108.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004232.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004233.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004234.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004235.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004236.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004239.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004450.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004507.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004508.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004509.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004510.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004511.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004519.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004520.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004521.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004522.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004682.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004684.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004685.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004688.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004777.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004778.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004779.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004780.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004781.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004782.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004784.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004785.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004786.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004787.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004788.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004799.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004835.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004836.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004838.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004846.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004848.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\004
# Saved enhanced audio for folder: 004849.mp3 in folder: D:\processed_audio_wav\fma_small\004
# Pre-processing folder: fma_small\005
# Saved enhanced audio for folder: 005006.mp3 in folder: D:\processed_audio_wav\fma_small\005
# Pre-processing folder: fma_small\005
# Saved enhanced audio for folder: 005156.mp3 in folder: D:\processed_audio_wav\fma_small\005
# Pre-processing folder: fma_small\005
# Saved enhanced audio for folder: 005157.mp3 in folder: D:\processed_audio_wav\fma_small\005
# Pre-processing folder: fma_small\005
# Saved enhanced audio for folder: 005158.mp3 in folder: D:\processed_audio_wav\fma_small\005
# Pre-processing folder: fma_small\005
# Saved enhanced audio for folder: 005159.mp3 in folder: D:\processed_audio_wav\fma_small\005
# Pre-processing folder: fma_small\005
# Saved enhanced audio for folder: 005169.mp3 in folder: D:\processed_audio_wav\fma_small\005
# Pre-processing folder: fma_small\005
# Saved enhanced audio for folder: 005170.mp3 in folder: D:\processed_audio_wav\fma_small\005
# Pre-processing folder: fma_small\005
# Saved enhanced audio for folder: 005171.mp3 in folder: D:\processed_audio_wav\fma_small\005
# Pre-processing folder: fma_small\005
# Saved enhanced audio for folder: 005191.mp3 in folder: D:\processed_audio_wav\fma_small\005
# Pre-processing folder: fma_small\005
# Saved enhanced audio for folder: 005264.mp3 in folder: D:\processed_audio_wav\fma_small\005
# Pre-processing folder: fma_small\005
# Saved enhanced audio for folder: 005268.mp3 in folder: D:\processed_audio_wav\fma_small\005
# Pre-processing folder: fma_small\005
# Saved enhanced audio for folder: 005376.mp3 in folder: D:\processed_audio_wav\fma_small\005
# Pre-processing folder: fma_small\005
# Saved enhanced audio for folder: 005381.mp3 in folder: D:\processed_audio_wav\fma_small\005
# Pre-processing folder: fma_small\005
# Saved enhanced audio for folder: 005521.mp3 in folder: D:\processed_audio_wav\fma_small\005
# Pre-processing folder: fma_small\005
# Saved enhanced audio for folder: 005879.mp3 in folder: D:\processed_audio_wav\fma_small\005
# Pre-processing folder: fma_small\005
# Saved enhanced audio for folder: 005936.mp3 in folder: D:\processed_audio_wav\fma_small\005
# Pre-processing folder: fma_small\005
# Saved enhanced audio for folder: 005940.mp3 in folder: D:\processed_audio_wav\fma_small\005
# Pre-processing folder: fma_small\006
# Saved enhanced audio for folder: 006329.mp3 in folder: D:\processed_audio_wav\fma_small\006
# Pre-processing folder: fma_small\006
# Saved enhanced audio for folder: 006330.mp3 in folder: D:\processed_audio_wav\fma_small\006
# Pre-processing folder: fma_small\006
# Saved enhanced audio for folder: 006331.mp3 in folder: D:\processed_audio_wav\fma_small\006
# Pre-processing folder: fma_small\006
# Saved enhanced audio for folder: 006332.mp3 in folder: D:\processed_audio_wav\fma_small\006
# Pre-processing folder: fma_small\006
# Saved enhanced audio for folder: 006333.mp3 in folder: D:\processed_audio_wav\fma_small\006
# Pre-processing folder: fma_small\006
# Saved enhanced audio for folder: 006342.mp3 in folder: D:\processed_audio_wav\fma_small\006
# Pre-processing folder: fma_small\006
# Saved enhanced audio for folder: 006354.mp3 in folder: D:\processed_audio_wav\fma_small\006
# Pre-processing folder: fma_small\006
# Saved enhanced audio for folder: 006357.mp3 in folder: D:\processed_audio_wav\fma_small\006
# Pre-processing folder: fma_small\006
# Saved enhanced audio for folder: 006358.mp3 in folder: D:\processed_audio_wav\fma_small\006
# ...
# Pre-processing folder: fma_small\058
# Saved enhanced audio for folder: 058061.mp3 in folder: D:\processed_audio_wav\fma_small\058
# Pre-processing folder: fma_small\058
# Saved enhanced audio for folder: 058063.mp3 in folder: D:\processed_audio_wav\fma_small\058
# Pre-processing folder: fma_small\058
# Saved enhanced audio for folder: 058068.mp3 in folder: D:\processed_audio_wav\fma_small\058
# Pre-processing folder: fma_small\058
# Saved enhanced audio for folder: 058070.mp3 in folder: D:\processed_audio_wav\fma_small\058
# Pre-processing folder: fma_small\058
# Saved enhanced audio for folder: 058115.mp3 in folder: D:\processed_audio_wav\fma_small\058
# Pre-processing folder: fma_small\058
# Saved enhanced audio for folder: 058116.mp3 in folder: D:\processed_audio_wav\fma_small\058
# Pre-processing folder: fma_small\058
# Saved enhanced audio for folder: 058117.mp3 in folder: D:\processed_audio_wav\fma_small\058
# Pre-processing folder: fma_small\058
# Saved enhanced audio for folder: 058135.mp3 in folder: D:\processed_audio_wav\fma_small\058
# Pre-processing folder: fma_small\058
# Saved enhanced audio for folder: 058140.mp3 in folder: D:\processed_audio_wav\fma_small\058
# Pre-processing folder: fma_small\058
# Saved enhanced audio for folder: 058161.mp3 in folder: D:\processed_audio_wav\fma_small\058
# Pre-processing folder: fma_small\058
# Saved enhanced audio for folder: 058162.mp3 in folder: D:\processed_audio_wav\fma_small\058
# Pre-processing folder: fma_small\058
# Saved enhanced audio for folder: 058164.mp3 in folder: D:\processed_audio_wav\fma_small\058
# Pre-processing folder: fma_small\058
# Saved enhanced audio for folder: 058166.mp3 in folder: D:\processed_audio_wav\fma_small\058
# Pre-processing folder: fma_small\058
# Saved enhanced audio for folder: 058169.mp3 in folder: D:\processed_audio_wav\fma_small\058
# Pre-processing folder: fma_small\058
# Saved enhanced audio for folder: 058170.mp3 in folder: D:\processed_audio_wav\fma_small\058
# Pre-processing folder: fma_small\058
# Saved enhanced audio for folder: 058173.mp3 in folder: D:\processed_audio_wav\fma_small\058
# Pre-processing folder: fma_small\058
# Saved enhanced audio for folder: 058174.mp3 in folder: D:\processed_audio_wav\fma_small\058
# Pre-processing folder: fma_small\058
# Saved enhanced audio for folder: 058207.mp3 in folder: D:\processed_audio_wav\fma_small\058
# Pre-processing folder: fma_small\058
# Saved enhanced audio for folder: 058212.mp3 in folder: D:\processed_audio_wav\fma_small\058
# Pre-processing folder: fma_small\058
# Saved enhanced audio for folder: 058213.mp3 in folder: D:\processed_audio_wav\fma_small\058
# Pre-processing folder: fma_small\058
# Saved enhanced audio for folder: 058215.mp3 in folder: D:\processed_audio_wav\fma_small\058
# Pre-processing folder: fma_small\058
# Saved enhanced audio for folder: 058221.mp3 in folder: D:\processed_audio_wav\fma_small\058
# Pre-processing folder: fma_small\058
# Saved enhanced audio for folder: 058225.mp3 in folder: D:\processed_audio_wav\fma_small\058
# Pre-processing folder: fma_small\058
# Saved enhanced audio for folder: 058333.mp3 in folder: D:\processed_audio_wav\fma_small\058
# Pre-processing folder: fma_small\058
# Saved enhanced audio for folder: 058334.mp3 in folder: D:\processed_audio_wav\fma_small\058
# Pre-processing folder: fma_small\058
# Saved enhanced audio for folder: 058341.mp3 in folder: D:\processed_audio_wav\fma_small\058
# Pre-processing folder: fma_small\058
# Saved enhanced audio for folder: 058474.mp3 in folder: D:\processed_audio_wav\fma_small\058
# Pre-processing folder: fma_small\058
# Saved enhanced audio for folder: 058539.mp3 in folder: D:\processed_audio_wav\fma_small\058
# Pre-processing folder: fma_small\058
# Saved enhanced audio for folder: 058540.mp3 in folder: D:\processed_audio_wav\fma_small\058
# Pre-processing folder: fma_small\058
# Saved enhanced audio for folder: 058541.mp3 in folder: D:\processed_audio_wav\fma_small\058
# Pre-processing folder: fma_small\058
# Saved enhanced audio for folder: 058542.mp3 in folder: D:\processed_audio_wav\fma_small\058
# Pre-processing folder: fma_small\058
# Saved enhanced audio for folder: 058543.mp3 in folder: D:\processed_audio_wav\fma_small\058
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059078.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059373.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059374.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059443.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059445.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059446.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059448.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059449.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059451.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059454.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059561.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059562.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059581.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059653.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059654.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059656.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059657.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059658.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059659.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059660.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059663.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059664.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059666.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059667.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059669.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059671.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059673.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059675.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059676.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059677.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059678.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059679.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059680.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059681.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059682.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059683.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059684.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059685.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059686.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059687.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059688.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059695.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059702.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059706.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059707.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059708.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059709.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059710.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059711.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059718.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059719.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059720.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059721.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059723.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059724.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059725.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059726.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059727.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059823.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059876.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\059
# Saved enhanced audio for folder: 059930.mp3 in folder: D:\processed_audio_wav\fma_small\059
# Pre-processing folder: fma_small\060
# Saved enhanced audio for folder: 060037.mp3 in folder: D:\processed_audio_wav\fma_small\060
# Pre-processing folder: fma_small\060
# Saved enhanced audio for folder: 060038.mp3 in folder: D:\processed_audio_wav\fma_small\060
# Pre-processing folder: fma_small\060
# Saved enhanced audio for folder: 060041.mp3 in folder: D:\processed_audio_wav\fma_small\060
# Pre-processing folder: fma_small\060
# Saved enhanced audio for folder: 060042.mp3 in folder: D:\processed_audio_wav\fma_small\060
# Pre-processing folder: fma_small\060
# Saved enhanced audio for folder: 060045.mp3 in folder: D:\processed_audio_wav\fma_small\060
# Pre-processing folder: fma_small\060
# Saved enhanced audio for folder: 060048.mp3 in folder: D:\processed_audio_wav\fma_small\060
# Pre-processing folder: fma_small\060
# Saved enhanced audio for folder: 060074.mp3 in folder: D:\processed_audio_wav\fma_small\060
# Pre-processing folder: fma_small\060
# Saved enhanced audio for folder: 060143.mp3 in folder: D:\processed_audio_wav\fma_small\060
# Pre-processing folder: fma_small\060
# Saved enhanced audio for folder: 060144.mp3 in folder: D:\processed_audio_wav\fma_small\060
# Pre-processing folder: fma_small\060
# Saved enhanced audio for folder: 060145.mp3 in folder: D:\processed_audio_wav\fma_small\060
# Pre-processing folder: fma_small\060
# Saved enhanced audio for folder: 060146.mp3 in folder: D:\processed_audio_wav\fma_small\060
# Pre-processing folder: fma_small\060
# Saved enhanced audio for folder: 060170.mp3 in folder: D:\processed_audio_wav\fma_small\060
# Pre-processing folder: fma_small\060
# Saved enhanced audio for folder: 060317.mp3 in folder: D:\processed_audio_wav\fma_small\060
# Pre-processing folder: fma_small\060
# Saved enhanced audio for folder: 060331.mp3 in folder: D:\processed_audio_wav\fma_small\060
# Pre-processing folder: fma_small\060
# Saved enhanced audio for folder: 060472.mp3 in folder: D:\processed_audio_wav\fma_small\060
# Pre-processing folder: fma_small\060
# Saved enhanced audio for folder: 060474.mp3 in folder: D:\processed_audio_wav\fma_small\060
# Pre-processing folder: fma_small\060
# Saved enhanced audio for folder: 060476.mp3 in folder: D:\processed_audio_wav\fma_small\060
# Pre-processing folder: fma_small\060
# Saved enhanced audio for folder: 060477.mp3 in folder: D:\processed_audio_wav\fma_small\060
# Pre-processing folder: fma_small\060
# Saved enhanced audio for folder: 060478.mp3 in folder: D:\processed_audio_wav\fma_small\060
# Pre-processing folder: fma_small\060
# Saved enhanced audio for folder: 060510.mp3 in folder: D:\processed_audio_wav\fma_small\060
# Pre-processing folder: fma_small\060
# Saved enhanced audio for folder: 060533.mp3 in folder: D:\processed_audio_wav\fma_small\060
# Pre-processing folder: fma_small\060
# Saved enhanced audio for folder: 060534.mp3 in folder: D:\processed_audio_wav\fma_small\060
# Pre-processing folder: fma_small\060
# Saved enhanced audio for folder: 060535.mp3 in folder: D:\processed_audio_wav\fma_small\060
# Pre-processing folder: fma_small\060
# Saved enhanced audio for folder: 060536.mp3 in folder: D:\processed_audio_wav\fma_small\060
# Pre-processing folder: fma_small\060
# Saved enhanced audio for folder: 060537.mp3 in folder: D:\processed_audio_wav\fma_small\060
# Pre-processing folder: fma_small\060
# Saved enhanced audio for folder: 060544.mp3 in folder: D:\processed_audio_wav\fma_small\060
# Pre-processing folder: fma_small\060
# Saved enhanced audio for folder: 060547.mp3 in folder: D:\processed_audio_wav\fma_small\060
# Pre-processing folder: fma_small\060
# Saved enhanced audio for folder: 060548.mp3 in folder: D:\processed_audio_wav\fma_small\060
# Pre-processing folder: fma_small\060
# Saved enhanced audio for folder: 060549.mp3 in folder: D:\processed_audio_wav\fma_small\060
# Pre-processing folder: fma_small\060
# Saved enhanced audio for folder: 060736.mp3 in folder: D:\processed_audio_wav\fma_small\060
# Error processing folder: D:\audio_sample\fma_small\060\060753.mp3

# %%
import os
import subprocess

def convert_to_mp3(input_path, output_folder):
    try:
        # Correct file extension if necessary
        if input_path.lower().endswith('.mp3.wav'):
            input_path = input_path[:-4]  # Remove the '.wav' part from the file name
        
        # Construct output path
        output_filename = os.path.splitext(os.path.basename(input_path))[0] + ".mp3"
        output_path = os.path.join(output_folder, output_filename)
        
        # Convert using ffmpeg
        subprocess.run(['ffmpeg', '-i', input_path, '-codec:a', 'libmp3lame', '-qscale:a', '2', output_path])
        
        print("Converted", input_path, "to MP3:", output_path)
    except Exception as e:
        print("Error converting:", input_path)
        print(e)

def convert_all_to_mp3(input_dir, output_dir):
    # Create output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)
    
    # Iterate through all subdirectories in the input directory
    for root, dirs, _ in os.walk(input_dir):
        for folder in dirs:
            # Construct input and output paths for the current subfolder
            subfolder_input_path = os.path.join(root, folder)
            subfolder_output_path = os.path.join(output_dir, os.path.basename(subfolder_input_path))
            os.makedirs(subfolder_output_path, exist_ok=True)
            
            # Iterate through all files in the current subfolder
            for file in os.listdir(subfolder_input_path):
                if file.lower().endswith('.wav'):
                    input_path = os.path.join(subfolder_input_path, file)
                    convert_to_mp3(input_path, subfolder_output_path)

# Constants
AUDIO_DIR = "D:\\processed_audio_wav"  # Input directory containing audio files
MP3_OUTPUT_DIR = "D:\\mp3_processed_audio"  # Output directory for converted MP3 files

# Convert all audio files in each subdirectory of the input directory to MP3
convert_all_to_mp3(AUDIO_DIR, MP3_OUTPUT_DIR)
# Out:
# Error converting: D:\processed_audio_wav\fma_small\000\000002.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000005.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000010.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000140.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000141.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000148.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000182.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000190.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000193.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000194.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000197.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000200.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000203.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000204.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000207.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000210.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000211.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000212.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000213.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000255.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000256.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000368.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000424.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000459.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000534.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000540.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000546.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000574.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000602.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000615.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000620.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000621.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000625.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000666.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000667.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000676.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000690.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000694.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000695.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000704.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000705.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000706.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000707.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000708.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000709.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000714.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000715.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000716.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000718.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000777.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000814.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000821.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000822.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000825.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000853.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000890.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000892.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000897.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000993.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000995.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000997.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\000\000998.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\001\001039.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\001\001040.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\001\001066.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\001\001069.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\001\001073.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\001\001075.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\001\001082.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\001\001083.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\001\001087.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\001\001102.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\001\001193.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\001\001195.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\001\001196.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\001\001197.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\001\001249.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\001\001259.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\001\001270.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\001\001276.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\001\
mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059449.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059451.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059454.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059561.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059562.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059581.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059653.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059654.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059656.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059657.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059658.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059659.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059660.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059663.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059664.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059666.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059667.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059669.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059671.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059673.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059675.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059676.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059677.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059678.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059679.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059680.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059681.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059682.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059683.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059684.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059685.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059686.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059687.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059688.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059695.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059702.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059706.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059707.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059708.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059709.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059710.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059711.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059718.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059719.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059720.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059721.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059723.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059724.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059725.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059726.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059727.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059823.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059876.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\059\059930.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\060\060037.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\060\060038.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\060\060041.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\060\060042.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\060\060045.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\060\060048.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\060\060074.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\060\060143.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\060\060144.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\060\060145.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\060\060146.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\060\060170.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\060\060317.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\060\060331.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\060\060472.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\060\060474.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\060\060476.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\060\060477.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\060\060478.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\060\060510.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\060\060533.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\060\060534.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\060\060535.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\060\060536.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\060\060537.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\060\060544.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\060\060547.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\060\060548.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\060\060549.mp3
# [WinError 2] The system cannot find the file specified
# Error converting: D:\processed_audio_wav\fma_small\060\060736.mp3
# [WinError 2] The system cannot find the file specified

# %%
import zipfile
import os

def extract_tracks_csv(zip_file_path, output_dir):
    # Create output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)
    
    with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
        for file_info in zip_ref.infolist():
            if file_info.filename.endswith('tracks.csv'):
                zip_ref.extract(file_info, output_dir)

# Example usage
ZIP_FILE_PATH = r"C:\Users\admin\Downloads\fma_metadata.zip"
OUTPUT_DIR = r"D:\track_metadata.csv"

extract_tracks_csv(ZIP_FILE_PATH, OUTPUT_DIR)

# %%
import pandas as pd

# Load track metadata with specified dtype to avoid mixed types warning
tracks = pd.read_csv(r"D:\track_metadata.csv\fma_metadata\tracks.csv", dtype=str)

# Flatten the hierarchy by selecting necessary columns
tracks_selected = tracks[['Unnamed: 0', 'comments', 'date_created', 'duration', 'favorites', 'genre_top', 'genres', 'title', 'album', 'artist', 'set']]

# Extract album metadata
albums = tracks_selected['album'].apply(lambda x: pd.Series(x.split('\t')))
albums.columns = [f'album_{i}' for i in range(1, len(albums.columns) + 1)]

# Extract artist metadata
artists = tracks_selected['artist'].apply(lambda x: pd.Series(x.split('\t')))
artists.columns = [f'artist_{i}' for i in range(1, len(artists.columns) + 1)]

# Extract set metadata
sets = tracks_selected['set'].apply(lambda x: pd.Series(x.split('\t')))
sets.columns = [f'set_{i}' for i in range(1, len(sets.columns) + 1)]

# Preprocess track metadata
# Drop original 'album', 'artist', and 'set' columns
tracks_selected.drop(['album', 'artist', 'set'], axis=1, inplace=True)

# Concatenate selected columns with extracted album, artist, and set metadata
tracks_preprocessed = pd.concat([tracks_selected, albums, artists, sets], axis=1)

# Convert date columns to datetime
tracks_preprocessed['date_created'] = pd.to_datetime(tracks_preprocessed['date_created'])

# Display the first few rows of preprocessed track metadata
print("\nPreprocessed Track Metadata:")
print(tracks_preprocessed.head())

# Display the shape of the preprocessed dataset
print("\nPreprocessed Tracks Dataset Shape:", tracks_preprocessed.shape)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 7
#       4 tracks = pd.read_csv(r"D:\track_metadata.csv\fma_metadata\tracks.csv", dtype=str)
#       6 # Flatten the hierarchy by selecting necessary columns
# ----> 7 tracks_selected = tracks[['Unnamed: 0', 'comments', 'date_created', 'duration', 'favorites', 'genre_top', 'genres', 'title', 'album', 'artist', 'set']]
#       9 # Extract album metadata
#      10 albums = tracks_selected['album'].apply(lambda x: pd.Series(x.split('\t')))
#
# File c:\Python312\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Python312\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File c:\Python312\Lib\site-packages\pandas\core\indexes\base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['comments', 'date_created', 'duration', 'favorites', 'genre_top', 'genres', 'title'] not in index"
